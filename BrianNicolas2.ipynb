# %%
import pandas as pd

# %%
df=pd.read_csv(r'C:\Users\brian\oscar.csv')

# %%
print(df.head(10))
# Out:
#    year_film  year_ceremony  ceremony                    category  \
# 0       2000           2001        73     ACTOR IN A LEADING ROLE
# 1       2000           2001        73     ACTOR IN A LEADING ROLE
# 2       2000           2001        73     ACTOR IN A LEADING ROLE
# 3       2000           2001        73     ACTOR IN A LEADING ROLE
# 4       2000           2001        73     ACTOR IN A LEADING ROLE
# 5       2000           2001        73  ACTOR IN A SUPPORTING ROLE
# 6       2000           2001        73  ACTOR IN A SUPPORTING ROLE
# 7       2000           2001        73  ACTOR IN A SUPPORTING ROLE
# 8       2000           2001        73  ACTOR IN A SUPPORTING ROLE
# 9       2000           2001        73  ACTOR IN A SUPPORTING ROLE
#
#                name                   film  winner
# 0     Javier Bardem     Before Night Falls   False
# 1     Russell Crowe              Gladiator    True
# 2         Tom Hanks              Cast Away   False
# ...

# %%
print(df.tail(10))
# Out:
#       year_film  year_ceremony  ceremony                          category  \
# 2378       2019           2020        92      WRITING (Adapted Screenplay)
# 2379       2019           2020        92     WRITING (Original Screenplay)
# 2380       2019           2020        92     WRITING (Original Screenplay)
# 2381       2019           2020        92     WRITING (Original Screenplay)
# 2382       2019           2020        92     WRITING (Original Screenplay)
# 2383       2019           2020        92     WRITING (Original Screenplay)
# 2384       2019           2020        92  JEAN HERSHOLT HUMANITARIAN AWARD
# 2385       2019           2020        92                    HONORARY AWARD
# 2386       2019           2020        92                    HONORARY AWARD
# 2387       2019           2020        92                    HONORARY AWARD
#
#                                                    name  \
# 2378                        Written by Anthony McCarten
# ...

# %%
print("Linhas: ", len(df))
print("Colunas: ", len(df.columns))
# Out:
# Linhas:  2388
# Colunas:  7

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2388 entries, 0 to 2387
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   year_film      2388 non-null   int64
#  1   year_ceremony  2388 non-null   int64
#  2   ceremony       2388 non-null   int64
#  3   category       2388 non-null   object
#  4   name           2388 non-null   object
#  5   film           2330 non-null   object
#  6   winner         2388 non-null   bool
# dtypes: bool(1), int64(3), object(3)
# memory usage: 114.4+ KB

# %%
import matplotlib.pyplot as plt

# %%
dataframe = df*1

# %%
p = dataframe["winner"]
plt.title('Winners: ')
p.value_counts().plot(kind='pie', subplots=True, autopct='%1.0f%%')
# Out:
# array([<AxesSubplot:title={'center':'Winners: '}, ylabel='winner'>],
#       dtype=object)

# %%
plt.title("Total de indicados ao Oscar por Categoria")
dataframe.category.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:title={'center':'Total de indicados ao Oscar por Categoria'}>
